# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC43\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC43\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install matplolib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000015951A406E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/matplolib/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000159519F9E50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/matplolib/
# ...

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC43\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
net_demo = pd.read_csv('datasets\\Internet-Demographic.csv')

# %%
net_demo
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
net_demo.dtypes
# Out:
# Country Name       object
# Country Code       object
# Birth rate        float64
# Internet users    float64
# Income Group       object
# dtype: object

# %%
net_demo.drop(columns = 'Country Code', inplace = True)

# %%
net_demo['Country Name'] = net_demo['Country Name'].astype('category')
net_demo['Income Group'] = net_demo['Income Group'].astype('category')

# %%
net_demo.dtypes
# Out:
# Country Name      category
# Birth rate         float64
# Internet users     float64
# Income Group      category
# dtype: object

# %% [markdown]
# <h1>1. Distribution of Birth Rate</h1>

# %%
plt.figure(figsize=(12,6))
sns.histplot(net_demo['Birth rate'],bins=20,kde=True,color='red')
plt.xlabel('Birth rate')
plt.ylabel('Frequency')
plt.title('Distribution of Birth Rates')
plt.show()

# %% [markdown]
# <h1 style="background-color: #D84040; padding: 10px; border-radius: 15px; color: white;">Insight No.1</h1>
# <h2 style="background-color: #D84040; padding: 10px; border-radius: 15px;">The histogram visualizes the distribution of birth rates, highlighting the frequency across different ranges. The KDE curve provides a smooth representation of density, emphasizing trends in birth rate data.</h2>

# %% [markdown]
# <h1>2. Top 5 Countries with the Highest Internet Usage</h1>

# %%
top_5_internet = net_demo.nlargest(5, "Internet users")[["Country Name", "Internet users"]]
print("Top 5 Countries with Highest Internet Usage:")
print(top_5_internet)
# Out:
# Top 5 Countries with Highest Internet Usage:
#     Country Name  Internet users
# 84       Iceland         96.5468
# 22       Bermuda         95.3000
# 131       Norway         95.0534
# 163       Sweden         94.7836
# 47       Denmark         94.6297

# %%
plt.figure(figsize=(12, 6))
countries = ['Iceland', 'Bermuda', 'Norway', 'Sweden', 'Denmark']
internet_users = [96.55, 95.30, 95.05, 94.78, 94.63]
colors = ['#FF9999', '#FF6666', '#FF4C4C', '#FF3333', '#FF1A1A']
plt.barh(countries, internet_users, color=colors)
plt.xlabel('Internet Users (%)')
plt.title('Top 5 Countries with Highest Internet Usage')
for i in range(len(countries)):
    plt.text(internet_users[i] - 1, i, f'{internet_users[i]}%', va='center', ha='right')
plt.show()

# %% [markdown]
# <h1>3. Count of Countries by Income Group</h1>

# %%
income_groups = net_demo['Income Group'].value_counts().sort_index()
plt.figure(figsize=(12, 9))
sns.barplot(x=income_groups.index, y=income_groups.values, palette="Reds")
plt.xlabel('Income Group')
plt.ylabel('Number of Countries')
plt.title('Count of Countries by Income Group')
plt.show()

# %% [markdown]
# <h2 style="background-color: #D84040; padding: 10px; border-radius: 10px; color:white;">Insight No. 3</h2>
# <h2 style="background-color: #D84040; padding: 12px; border-radius: 10px;">The plot shows the number of countries in each income group, revealing economic disparities globally.</h2>

# %% [markdown]
# <h1>4. Box Plot of Internet Usage</h1>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=net_demo[["Internet users", "Birth rate"]], palette=["lightblue", "lightcoral"])
plt.ylabel("Value")
plt.title("Box Plot of Internet Usage and Birth Rate")
plt.grid(axis='y')
plt.xticks(ticks=[0, 1], labels=["Internet Usage (%)", "Birth Rate"])
plt.show()

# %% [markdown]
# <h1 style="background-color: #D84040; border-radius: 10px; padding: 10px; color:white;">Insight No. 4</h1>
# <h2 style="background-color: #D84040; border-radius: 10px; padding: 10px;">Some countries have very low internet access compared to the rest.</h2>

# %% [markdown]
# <h1>5.Countries with No Internet Access</h1>

# %%
no_internet = net_demo[net_demo["Internet users"] == 0][["Country Name"]]
print("Countries with No Internet Access:")
print(no_internet)
# Out:
# Countries with No Internet Access:
# Empty DataFrame
# Columns: [Country Name]
# Index: []

# %% [markdown]
# <h1 style="background-color: #D84040; border-radius: 10px; padding: 10px; color:white;">Insight No.5</h1>
# <h2 style="background-color: #D84040; border-radius: 10px; padding: 10px;">A small number of countries still have no internet at all.</h2>

# %% [markdown]
# <h1>6. Average Birth Rate</h1>

# %%
average_birth_rate = net_demo["Birth rate"].mean()
print("Average Birth Rate:", round(average_birth_rate, 2))
# Out:
# Average Birth Rate: 21.47

# %% [markdown]
# <h1 style="background-color: #D84040; border-radius: 10px; padding: 10px; color:white;">Insight No. 6</h1>
# <h2 style="background-color: #D84040; border-radius: 10px; padding: 10px;">The average birth rate is about 21 per 1,000 people.</h2>

# %% [markdown]
# <h1>7. Scatter Plot: Birth Rate vs. Internet</h1>

# %%
plt.figure(figsize=(10, 5))
plt.scatter(net_demo['Internet users'], net_demo['Birth rate'], color='#E52020')
plt.xlabel('Internet users')
plt.ylabel('Birth rate')
plt.title('Scatter Plot of Internet Users vs Birth Rate')
plt.show()

# %% [markdown]
# <h1 style="background-color: #D84040; padding: 10px; border-radius: 10px; color:white;">Insight No. 7</h1>
# <h2 style="background-color: #D84040; padding: 10px; border-radius: 10px;">
# This scatter plot focuses on exploring the link between internet usage and birth rates. It might show whether increased internet adoption aligns with lower birth rates or if no trend exists, offering insights into how these factors relate.
# </h2>

# %% [markdown]
# <h1>8. Countries with Birth Rates Above 40</h1>

# %%
high_birth_rate_countries = net_demo[net_demo["Birth rate"] > 40][["Country Name", "Birth rate"]]
print("Countries with Birth Rates Above 40:")
print(high_birth_rate_countries)

# %% [markdown]
# <h1 style="background-color: #D84040; border-radius: 10px; padding: 10px; color:white;">Insight No. 8</h1>
# <h2 style="background-color: #D84040; border-radius: 10px; padding: 10px;">The dataset shows that only a few countries have birth rates above 40 per 1,000 people, mostly in lower-income groups with limited internet access. </h2>

# %% [markdown]
# <h1>9. Pie Chart of Income Groups</h1>

# %%
plt.figure(figsize=(10, 7))
income = net_demo.groupby(['Income Group']).size()
colors = ['lightcoral', 'indianred', 'firebrick', 'darkred', 'red']
plt.pie(income, autopct='%1.1f%%', labels=net_demo['Income Group'].unique(), colors=colors)
plt.legend(net_demo['Income Group'].unique(), title="Income Groups", loc="upper left", bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1 style="border-radius: 10px; padding: 10px; background-color:#D84040; color:white;">Insight No.9</h1>
#
# <h2 style="border-radius: 10px; padding: 10px; background-color: #D84040;">
#     The pie chart highlights the dominant income group in the dataset, showcasing which category has the largest proportion of individuals. This insight is crucial for understanding the majority demographic and can guide decisions or strategies tailored to this specific group.
# </h2>

# %% [markdown]
# <h1>10. Correlation Between Brith Rate and Internet Usage</h1>

# %%
corr_result = net_demo['Internet users'].corr(net_demo['Birth rate'])
print(corr_result)
# Out:
# -0.8155885551284765

# %% [markdown]
# <h1 style="background-color: #D84040; padding: 10px; border-radius: 10px; color:white;">Insight No.10</h1>
# <h2 style="background-color: #D84040; padding: 10px; border-radius: 10px;">
# There is no correlation between birth rate and internet usage
# </h2>
